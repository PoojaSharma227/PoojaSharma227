# %% [markdown]
# **TECHNOHACKS EDU TECH**
#
# **NAME:** **POOJA SHARMA**
#
# **TASK 1:** **DATA CLEANING**
#
# **BATCH:** **10**
#
# **DOMAIN:** **DATA ANALYTICS**

# %%
#Import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#collecting dataset

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5fdf814d-f5e8-4837-83f8-c5bddb2977cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fdf814d-f5e8-4837-83f8-c5bddb2977cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#reading CSV file

dataset = pd.read_csv('train.csv')
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#checking null values

dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# checking null values using the heatmap for better results
sns.heatmap(dataset.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
# to make age prediction, we need to find the Age pattern by plotting the Age on the charts
sns.boxplot(x = 'Pclass', y = 'Age', data = dataset, palette='summer')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
# as we can see that in Pclass 1 the age is approx 37 according to 50th percentile, 29 in Pclass 2 and 24 in Pclass 3.
# so according to that we will make this estimation and put the age respectively
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]

    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
# now applying this function to make changes
dataset["Age"] = dataset[['Age', 'Pclass']].apply(impute_age, axis = 1)
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.drop('Cabin', axis=1, inplace=True)
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#confirming the changes
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
#eliminating missing values from "Embraked"
dataset_cleaned = dataset.dropna()
dataset_cleaned
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(dataset_cleaned.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# **dataset is cleaned**

# %% [markdown]
# **IQR METHOD**

# %%
#finding the IQR
percentile25 = dataset_cleaned['Age'].quantile(0.25)
percentile75 = dataset_cleaned['Age'].quantile(0.75)
print(percentile25)
print(percentile75)
# Out:
# 22.0
# 36.5

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# 14.5

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print("upper_limit", upper_limit)
print("lower_limit", lower_limit)
# Out:
# upper_limit 58.25
# lower_limit 0.25

# %%
condition = dataset[dataset['Age'] > upper_limit]

# %%
condition = dataset[dataset['Age'] < lower_limit]

# %% [markdown]
# **CAPPING METHOD TO REMOVE OUTLIERS IN DATASET**

# %%
Dataset_cap = dataset.copy()

Dataset_cap['Age'] = np.where(
    Dataset_cap['Age'] > upper_limit,
    upper_limit,
    np.where(
        Dataset_cap['Age'] < lower_limit,
        lower_limit,
        Dataset_cap['Age']
    )
)

# %%
np.where(condition,True,False)
# Out:
# array([], shape=(0, 11), dtype=bool)

# %%
Dataset_cap.shape
# Out:
# (891, 11)

# %%
sns.boxplot(x = 'Pclass', y = 'Age', data = Dataset_cap, palette='summer')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#triming the outliers from the dataset
new_dataset = dataset.loc[(dataset['Age'] < upper_limit) & (dataset_cleaned['Age'] > lower_limit)]
print('before removing outliers:', len(dataset))
print('after removing outliers:', len(new_dataset))
print('outliers:', len(dataset) - len(new_dataset))
# Out:
# before removing outliers: 891
# after removing outliers: 862
# outliers: 29

# %%
sns.boxplot(x = 'Pclass', y = 'Age', data = new_dataset, palette='summer')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
